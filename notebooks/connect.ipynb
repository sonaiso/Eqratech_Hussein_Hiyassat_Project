# %% [markdown]
# <a href="https://colab.research.google.com/github/salemqundil/Eqratech_Arabic_Diana_Project/blob/main/connect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#     !pip install colabcode

# %%
# !pip install torch

# %%
# !pip install --upgrade transformers accelerate

# %%
# !pip install --upgrade transformers accelerate datasets tokenizers sentencepiece --quiet

# %%
# ✅ Colab-ready: PyTorch + CUDA check
import platform
import torch

# ⚠️ تم استبدال هذا الدفتر

---

## Please use the new comprehensive notebook:
## الرجاء استخدام الدفتر الشامل الجديد:

### 👉 [Open Eqratech_Arabic_Colab.ipynb](https://colab.research.google.com/github/salemqundil/Eqratech_Arabic_Diana_Project/blob/main/Eqratech_Arabic_Colab.ipynb)

---

The new notebook includes:
- Complete project setup and installation
- Multiple usage examples
- Arabic text processing demonstrations
- Full grammar export functionality

يتضمن الدفتر الجديد:
- إعداد وتثبيت كامل للمشروع
- أمثلة استخدام متعددة
- عروض توضيحية لمعالجة النصوص العربية
- وظيفة تصدير القواعد الكاملة

# %% [markdown]
# ---
#
# ### Quick Start / البدء السريع
#
# Click the button below to go to the main notebook:
#
# [![Open Main Notebook](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/salemqundil/Eqratech_Arabic_Diana_Project/blob/main/Eqratech_Arabic_Colab.ipynb)
